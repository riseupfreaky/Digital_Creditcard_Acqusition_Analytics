# %%
# create synthetic csv file

import csv

filepath= r'C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\channel_spend.csv'

column_headers = ['date', 'channel', 'spend']

with open(filepath, mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(column_headers)

print(f"✅ Blank CSV file created successfully at: {filepath}")
# Out:
# ✅ Blank CSV file created successfully at: C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\channel_spend.csv

# %%
import csv
filepath=r'C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\impressions_clicks.csv'

column_headers=['date','channel','impressions','clicks']
with open(filepath, mode='w', newline='') as file:
    writer=csv.writer(file)

    writer.writerow(column_headers)

print(f"✅ Blank CSV file created successfully at: {filepath}")
# Out:
# ✅ Blank CSV file created successfully at: C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\impressions_clicks.csv

# %%
import csv
filepath=r'C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\app_funnel.csv'

column_headers=['customer_id', 'app_start', 'app_complete', 'approved', 'activated']
with open(filepath, mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(column_headers)

print(f"✅ Blank CSV file created successfully at: {filepath}")
# Out:
# ✅ Blank CSV file created successfully at: C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\app_funnel.csv

# %%
import csv
filepath=r'C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\retail_qr_scans.csv'
column_headers=['store_id', 'date', 'scans', 'approvals']

with open(filepath, mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(column_headers)
print(f"✅ Blank CSV file created successfully at: {filepath}")
# Out:
# ✅ Blank CSV file created successfully at: C:\Users\freak\.cache\kagglehub\datasets\Syntheticdatacsvs\retail_qr_scans.csv

# %%
print("📄 Contents of the CSV file:")
print("-" * 40)

with open(filepath, mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
print("-" * 40)
# Out:
# 📄 Contents of the CSV file:
# ----------------------------------------
# ['store_id', 'date', 'scans', 'approvals']
# ----------------------------------------

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rikdifos/credit-card-approval-prediction")

print("Path to dataset files:", path)
